# %%
pip install numpy

# %%
import numpy as np
one=np.array([1,2,3])
print(one)
print(one.ndim)
print(type(one))
print(one.strides)
print(one.data)
# Out:
# [1 2 3]
# 1
# <class 'numpy.ndarray'>
# (8,)
# ...

# %%
np.__version__
# Out:
# '1.18.5'

# %%
type(one[1])
# Out:
# numpy.int64

# %%
import numpy as np
a=np.array([[1,2,3]])
