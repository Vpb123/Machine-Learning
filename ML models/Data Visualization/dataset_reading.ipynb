# %% [markdown]
# #### Dataset reading

# %% [markdown]
# Using url

# %%
import pandas as pd
pd.read_csv("https://lovespreadsheet-tutorials.s3.amazonaws.com/APIDatasets/indian_liver_patient_dataset.csv")
# Out:
#      age  gender    TB   DB  alkphos  sgpt   sgot   TP  ALB   A_G  class
# 0     65  Female   0.7  0.1    187.0  16.0   18.0  6.8  3.3  0.90    1.0
# 1     62    Male  10.9  5.5    699.0  64.0  100.0  7.5  3.2  0.74    1.0
# 2     62    Male   7.3  4.1    490.0  60.0   68.0  7.0  3.3  0.89    1.0
# 3     58    Male   1.0  0.4    182.0  14.0   20.0  6.8  3.4  1.00    1.0
# 4     72    Male   3.9  2.0    195.0  27.0   59.0  7.3  2.4  0.40    1.0
# ..   ...     ...   ...  ...      ...   ...    ...  ...  ...   ...    ...
# 578   60    Male   0.5  0.1    500.0  20.0   34.0  5.9  1.6  0.37    2.0
# 579   40    Male   0.6  0.1     98.0  35.0   31.0  6.0  3.2  1.10    1.0
# 580   52    Male   0.8  0.2    245.0  48.0   49.0  6.4  3.2  1.00    1.0
# 581   31    Male   1.3  0.5    184.0  29.0   32.0  6.8  3.4  1.00    1.0
# 582   38    Male   1.0  0.3    216.0  21.0   24.0  7.3  4.4  1.50    2.0
#
# [583 rows x 11 columns]

# %% [markdown]
# uploading from local machine

# %%
from google.colab import files
import io
uploaded=files.upload()
df = pd.read_csv(io.BytesIO(uploaded['indian_liver_patient.csv']))
df
# Out:
#      <input type="file" id="files-c5e6fea6-67cf-49ad-b62c-df8e79e8df48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5e6fea6-67cf-49ad-b62c-df8e79e8df48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving indian_liver_patient.csv to indian_liver_patient.csv
#      Age  Gender  Total_Bilirubin  ...  Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0     65  Female              0.7  ...      3.3                        0.90        1
# 1     62    Male             10.9  ...      3.2                        0.74        1
# 2     62    Male              7.3  ...      3.3                        0.89        1
# 3     58    Male              1.0  ...      3.4                        1.00        1
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/My Drive/datasets/indian_liver_patient.csv')
df
# Out:
#      Age  Gender  Total_Bilirubin  ...  Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0     65  Female              0.7  ...      3.3                        0.90        1
# 1     62    Male             10.9  ...      3.2                        0.74        1
# 2     62    Male              7.3  ...      3.3                        0.89        1
# 3     58    Male              1.0  ...      3.4                        1.00        1
# 4     72    Male              3.9  ...      2.4                        0.40        1
# ..   ...     ...              ...  ...      ...                         ...      ...
# 578   60    Male              0.5  ...      1.6                        0.37        2
# 579   40    Male              0.6  ...      3.2                        1.10        1
# 580   52    Male              0.8  ...      3.2                        1.00        1
# 581   31    Male              1.3  ...      3.4                        1.00        1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')
