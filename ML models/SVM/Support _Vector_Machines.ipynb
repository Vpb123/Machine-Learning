# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Importing dataset

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/datasets/pulsar_stars.csv")

# %% [markdown]
# #### EDA

# %%
df.shape
# Out:
# (17898, 9)

# %%
df.head()
# Out:
#     Mean of the integrated profile  ...  target_class
# 0                       140.562500  ...             0
# 1                       102.507812  ...             0
# 2                       103.015625  ...             0
# 3                       136.750000  ...             0
# 4                        88.726562  ...             0
#
# [5 rows x 9 columns]

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Mean of the integrated profile',
#        'Standard deviation of the integrated profile',
#        'Excess kurtosis of the integrated profile',
#        'Skewness of the integrated profile', 'Mean of the DM-SNR curve',
#        'Standard deviation of the DM-SNR curve',
#        'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
df.columns= ['IP Mean', 'IP Sd', 'IP Kurtosis', 'IP Skewness', 
              'DM-SNR Mean', 'DM-SNR Sd', 'DM-SNR Kurtosis', 'DM-SNR Skewness', 'target_class']

# %%
df.columns
# Out:
# Index(['IP Mean', 'IP Sd', 'IP Kurtosis', 'IP Skewness', 'DM-SNR Mean',
#        'DM-SNR Sd', 'DM-SNR Kurtosis', 'DM-SNR Skewness', 'target_class'],
#       dtype='object')

# %%
df["target_class"].value_counts()
# Out:
# 0    16259
# 1     1639
# Name: target_class, dtype: int64

# %%
#Checking for missing values in the variabels
df.isnull().sum()
# Out:
# IP Mean            0
# IP Sd              0
# IP Kurtosis        0
# IP Skewness        0
# DM-SNR Mean        0
# DM-SNR Sd          0
# DM-SNR Kurtosis    0
# DM-SNR Skewness    0
# target_class       0
# dtype: int64

# %%
#Checking for outliers

plt.figure(figsize=(24,20))


plt.subplot(4, 2, 1)
fig = df.boxplot(column='IP Mean')
fig.set_title('')
fig.set_ylabel('IP Mean')


plt.subplot(4, 2, 2)
fig = df.boxplot(column='IP Sd')
fig.set_title('')
fig.set_ylabel('IP Sd')


plt.subplot(4, 2, 3)
fig = df.boxplot(column='IP Kurtosis')
fig.set_title('')
fig.set_ylabel('IP Kurtosis')


plt.subplot(4, 2, 4)
fig = df.boxplot(column='IP Skewness')
fig.set_title('')
fig.set_ylabel('IP Skewness')


plt.subplot(4, 2, 5)
fig = df.boxplot(column='DM-SNR Mean')
fig.set_title('')
fig.set_ylabel('DM-SNR Mean')


plt.subplot(4, 2, 6)
fig = df.boxplot(column='DM-SNR Sd')
fig.set_title('')
fig.set_ylabel('DM-SNR Sd')


plt.subplot(4, 2, 7)
fig = df.boxplot(column='DM-SNR Kurtosis')
fig.set_title('')
fig.set_ylabel('DM-SNR Kurtosis')


plt.subplot(4, 2, 8)
fig = df.boxplot(column='DM-SNR Skewness')
fig.set_title('')
fig.set_ylabel('DM-SNR Skewness')
# Out:
# Text(0, 0.5, 'DM-SNR Skewness')

# %% [markdown]
# There are lot of outliers in these variables and also the variables are skewed

# %% [markdown]
# #### Spliting the dataset

# %%
X= df.drop(['target_class'], axis=1)

y=df['target_class']

from sklearn.model_selection import train_test_split

X_train , X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((14318, 8), (3580, 8))

# %% [markdown]
# ### Feature Scaling

# %%
cols= X_train.columns

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_train= scaler.fit_transform(X_train)

X_test = scaler.fit_transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=[cols])
X_test = pd.DataFrame(X_test, columns=[cols])
X_train.describe()
# Out:
#             IP Mean         IP Sd  ... DM-SNR Kurtosis DM-SNR Skewness
# count  1.431800e+04  1.431800e+04  ...    1.431800e+04    1.431800e+04
# mean   1.986604e-16 -6.757488e-16  ...   -9.700300e-18    1.214786e-16
# std    1.000035e+00  1.000035e+00  ...    1.000035e+00    1.000035e+00
# min   -4.035499e+00 -3.181033e+00  ...   -2.455649e+00   -1.003411e+00
# 25%   -3.896291e-01 -6.069473e-01  ...   -5.641035e-01   -6.627590e-01
# 50%    1.587461e-01  5.846646e-02  ...    3.170446e-02   -2.059136e-01
# 75%    6.267059e-01  6.501017e-01  ...    5.362759e-01    3.256217e-01
# max    3.151882e+00  7.621116e+00  ...    5.818557e+00    1.024613e+01
#
# [8 rows x 8 columns]

# %% [markdown]
# ### Running SVM with default hyperparameters

# %%
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score
svc=SVC()

svc.fit(X_train, y_train)

y_predicted = svc.predict(X_test)

# %%
print('Model accuracy score with default hyperparameters:',(accuracy_score(y_test, y_predicted)))
# Out:
# Model accuracy score with default hyperparameters: 0.9829608938547486

# %% [markdown]
# #### Running SVM with rbf kernel and c=100.0

# %%
svc=SVC(C=100.0) 

svc.fit(X_train,y_train)

y_pred_test=svc.predict(X_test)
print('Model accuracy score with rbf kernel and C=100.0 :', accuracy_score(y_test, y_pred_test))
# Out:
# Model accuracy score with rbf kernel and C=100.0 : 0.9846368715083799

# %%
y_pred_train = svc.predict(X_train)
print('Training-set accuracy score:',(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 0.9829585137589049

# %% [markdown]
# #### Checking for Overfitting

# %%
print('Training set score: {:.4f}'.format(svc.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(svc.score(X_test, y_test)))
# Out:
# Training set score: 0.9830
# Test set score: 0.9846

# %% [markdown]
# There is no overfitting here as both model accuracy score are quit comperable

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred_test)
conf_matrix= pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])
conf_matrix
# Out:
#                     Actual Positive:1  Actual Negative:0
# Predict Positive:1               3284                 22
# Predict Negative:0                 33                241

# %%
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='YlGnBu')
