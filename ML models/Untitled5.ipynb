# %%
# !git clone https://github.com/OanaGaskey/Route-Planner.git
# Out:
# Cloning into 'Route-Planner'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 39 (delta 15), reused 28 (delta 8), pack-reused 0
# Unpacking objects: 100% (39/39), done.

# %%
# !pip install chart-studio
# Out:
# ...
#      |████████████████████████████████| 71kB 4.4MB/s
# ...

# %%
from helpers import Map, load_map_10, load_map_40, show_map
import math

# %load_ext autoreload
# %autoreload 2
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
map_10 = load_map_10()
show_map(map_10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7df94ed32afc> in <module>()
# ----> 1 map_10 = load_map_10()
#       2 show_map(map_10)
#
# NameError: name 'load_map_10' is not defined
